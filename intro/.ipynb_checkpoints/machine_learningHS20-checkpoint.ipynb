# %% [markdown]
# # Supervised Learning
#
# * regression
#
# <img src="attachment:regression.png" width="300">
#
# e.g. forecasting the prices of dwellings on the basis of their attributes (location, size, etc.)
#
# * classification
#
# ![classifier.png](attachment:classifier.png)
#
# e.g. Spam versus Non-Spam
#
# Note: in both cases we are looking for a hyperplane that best approximates (regression) or separates (classification) some data points. In both cases we follow the same underlying idea of cost (error) minimization.
# However in regression, we take the predicted (real) value, in classification we map the predicted value to a discrete class. We then simply ask whether a data point is below (-1) or above the hyperplane.

# %% [markdown]
# # Finding a Separating Hyperplane
#
# two points: blue and green
#
# examples: (2,2) = blue and (2,4) = green
#
# we would like to find a separating/approximating hyperpline (a line in our case)
#
# general form of a linear classifier: $$f(y)=b + \sum_{i=1}^n w_i*x_i$$
# where $b$ is called bias $w_i$ a weight and $x_i$ the i-th feature
#
# we can absorb $b$ in the weights by setting (a dummy feature) e.g. $x_0=1$. $b$ then can be learned with same mechanism as the other weights:
#
#  $$f(y)=\sum_{i=0}^n w_i*x_i$$ we know, this is the dot product of vectors: $$\vec{w} \cdot \vec{x}$$
#
#  * in regression $y$ is a real values (e.g. prices of dwellings)
#  * in classification $y$ get mapped to a class, e.g. by the sign function

# %%
import matplotlib.pyplot as plt

# first arg: x values, sec. arg: y values
plt.plot([0,2,3],[0,3,4.5])
plt.plot([2],[2],'bo')
plt.plot([2],[4],'go')

plt.show()

# %% [markdown]
# Note: there are many separating/approximating lines!
#
# e.g. f(x) = 1.5 x + 0
#
# we drop b, which is 0 in our case

# %%
plt.plot([0,2,3],[1,3,4])
plt.plot([2],[2],'bo')
plt.plot([2],[4],'go')
plt.plot([0],[0])

plt.show()

# %%
plt.plot([0,2,4],[3,3,3])
plt.plot([2],[2],'bo')
plt.plot([2],[4],'go')
plt.plot([0],[0])

plt.show()

# %%
# back to f(x)=1,5x

plt.plot([0,2,3],[0,3,4.5])
plt.plot([2],[2],'bo')
plt.plot([2],[4],'go')

plt.show()

# %% [markdown]
# # Classification based on the sign
#
# If the two points are members of distinct classes, we take the sign as class indicator. Note, however, that we currently do not take the class information into account at learning time (we do it below).
#
# hyperplane: $y = x_2 = 1.5 x_1 + 0$
#
# * $x^j = (x_1,x_2)$ ($j$ is example index, $y=x_2$)
#
#
# * $x^1 = (2,4)$
# * $x^2 = (2,2)$
#
#
# * $x_2 = 1.5 x_1 + 0 = 1.5 x_1$  (the hyperplane)
#
# * $x_2 = 1.5 x_1$
#
# * we tranform the hyperplane to a format that acts as a decision boundary:
#   * $x_2 - 1.5 x_1 = 0~~~~$or $~~~~ -1.5 x_1 + x_2 = 0$
#
#
# * all points that are (lie) on the hyperplane satisfy this equation
#
#
# * points above the line do not satisfy the equation, but they yield a value indicating the position either above or below the line
#
# ## positive versus negative sign
#
# if we instantiate the formula with the example feature vectors $x^j$, i.e. (2,4) and (2,2), we get:
#
# * $x^1 = 4 - 1.5*2 = 1$     point = above
#
#
# * $x^2 = 2 - 1.5*2 = -1 $   point = below
#
#
# ## the sign function for mapping arbitrary values to -1 (below) or 1 (above)
#
# * $x^3 = (2,5)$
#
#
# * $x^3 = 5 - 1.5*2 = 2$
#
#
# * we use: $sign(-1.5 x_1 + x_2)$
#
#
# * i.e. $sign(5 -1.5 * 2)$

# %%
import numpy as np

np.sign(5 -1.5 * 2)
# Out:
# 1.0

# %% [markdown]
# ## summary notation
#
# $w_1x_1 + w_2x_2-b$ bzw. $0.5x_1 +x_2 - 1.5 = 0$
#
#
# notation as dot product: $\vec{w} \cdot \vec{x} - b$
#
#  * $\vec{w}$ = $\langle 0.5, 1 \rangle$ and $\vec{x}= \langle x_1, x_2 \rangle$  are vectors with $w_1=0.5$ etc.
#
#
#  * $\vec{w}$ is the weight vector, $\vec{x}$ is the feature vector
#
# * absorbing $b$: $\vec{w}$ = $\langle -1.5, 0.5, 1 \rangle$ and $\vec{x}= \langle x_0, x_1, x_2 \rangle$  with $x_0=1$, then we have: $\vec{w} \cdot \vec{x} $
#
# ## another notation variant
#
# Round brackets are used to denote (column and row) vectors. Mostly we assume that vectors are column vectors, so we have to transpose, i.e. $w^T$ (now we don't use arrows anymore).
#
# transponation: we swap columns and rows
#
# the weight vector looks like this (as default column vector):
#
#
# * $w= \left( \begin{array}{c} 0.5 \\ 1 \end{array} \right)  $
# * $w^T$ = transponation , i.e.   $\left( \begin{array}{c} 0.5 \\ 1 \end{array} \right)$  becomes  $( 0.5, 1 )$
# * i.e. the second entry of the first column givest the second entry of the first row
#
#
# * $\left( \begin{array}{cc} 0.5 & 1 \end{array} \right)$ $\left( \begin{array}{c} x_1 \\ x_2 \end{array} \right) - 1.5 $
#
#
#
# * matrix multiplication: column times row (multipication in the sense of dot product)
#
# ## we can write it as:
#
# * $w_0x_0 + w_1x_1 + \ldots + w_nx_n $ $ ~~~$or
#
#
# *  $\sum_{i=0}^n w_i*x_i$ $ ~~~$or
#
#
# * $\vec{w} \cdot \vec{x} $ $ ~~~$or
#
#
# * $w^T\vec{x}$$ ~~~$ or$ ~~~$ $w^T{x}$
#
#
# ## DL version
#
# as soon as we deal with Deep Learning (DL), we have a weight matrix: $ ~~~$$xW$ $ ~~~$or$ ~~~$ $xW+b$

# %% [markdown]
# ## How to find/induce the hyperplane
#
# two ways:
#
# * we define a error function and set the first derivative to zero and resolve it
# * we define a error function and iteratively search for the minimal errors
#
# ### Costs (as a function of the weights)
#
# we initiate the weight vector randomly (!), say:
#
# * $\vec{w} = w = (0.5)$  (weight vector)
#
# we drop the arrow from vectors from now on
#
# this is $f(x) = 0.5x + 0$ (we drop b which is 0)
#
# $f(x) = 0.5x$

# %%
# the curve of f(x)=0.5x

plt.plot([0,2,4],[0,1,2])
plt.plot([2],[2],'bo')
plt.plot([2],[4],'go')

plt.show()

# %% [markdown]
# ## Learning = Minimizing Prediction Errors
#
#
# $y_{pred}=f_{pred}(x)=0.5x$
#
# $y_{pred}=f_{pred}(2) = y_{pred}= 1$ (Prediction for feature value x=2)
#
# What is the error we make?
#
# Error: sum of the errors wrt. to all instances $j$ (training examples)
#
# We have two (superscript as example index): $x^j $
#
# * $x^1 = f_{obs}(2)= 4$
# * $x^2 = f_{obs}(2)= 2$
#
# Sum of Errors: error for $x^1$ + error for $x^2$
#
# Single Error $e^j$: real y minus predicted y
#
# * $e^1 = 4 - 1 = 3$
# * $e^2 = 2 - 1 = 1$
#
# * $e^1 + e^2 = 3 + 1 = 4$
#
#
# In order to penalize larger error (and to simplify minimization) we square the errors!
#
#
#
# * $e^1 = (4 - 1)^2 = 9$
# * $e^2 = (2 - 1)^2 = 1$
#
#
# * $e^1 + e^2 = 9 + 1 = 10$
#
# In general:
#
#  $$J(w) = \sum_{j=0}^M(y_{obs}^j - y_{pred}^j)^2~~~ or~~~ J(w) = \sum_{j=0}^M(y^j - w^Tx^j)^2  $$
#
#
#  $$J(w) = \sum_{j=0}^M(y_{obs}^j - y_{pred}^j)^2 = (4-1)^2 + (2-1)^2 = 10$$
#
# where M denotes the number of training examples
#
# Please note that we are dealing with the simplest case, so the weight vector $w$ just comprises one entry, it is ($0.5$), so $w^T=w$
#
#
# ## Cost Function $J$
#
# We call $J$ the cost function, it is a function of the weight vector $w$
#
# $J$ is a convex function, it general shape is $x^2$, the prototypical convex function.
#
# The good news: convex function have a global minimum.
#
# A convex function is like a salad bowl, each ball rolls down to its lowest point.
#
# ![saladbowl.png](attachment:saladbowl.png)
#
#
# The global minimum gives us the best approximation, because it minimizes the error we make!

# %% [markdown]
#
#  Goal: find a weight vector such that the prediction error is minimal. We call it *least square approximation*.
#
#
#  The first derivation of $J$ gives us the slope (gradient), we set it to zero to get the minimum.
#
#
#  Figure: 1. curve is convex, 2. curve not. "convex: there exist no line that crosses the curve more than once
#
#  ![convex_function.png](attachment:convex_function.png)
#  ![non_convex_function.png](attachment:non_convex_function.png)

# %% [markdown]
# ## First derivative equals zero
#
#
# Our general formula is (restriction on two-dimensional cases): $f(x)=wx + b$
#
#  $$J(w,b) = \sum_{j=0}^M(y^j - f(x^j))^2  ~~~or ~~~J(w,b) = \sum_{j=0}^M(y^j - wx^j - b)^2$$
#
#
# partial derivative towards $b$:
#
# $$J'(w,b) = \frac{\delta J(w,b)}{\delta b}= \sum_{i=1}^n[2(y_i - wx_i -b)(-1)]=0$$
#
# Note: in the derivation we use $i$ instead of $j$. Moreover, we subscript instead of superscribe.
# $x_1$ means: the value for coordinate $x$ of example 1; $x_2$ is the value for coordinate $x$ of example 2, etc., $y_1$ accordingly is the value of $y$ of example 1.
#
# ### Chain rule
#
#
# * $f'(g(x)) = f'(g(x)) * g'(x)$
#
# * outer function: $(y^j - wx^j - b)^2$ taking the square
# * inner function: $(y^j - wx^j - b)$ the linear equation
#
# * outer function derivative: $2(y^j - wx^j - b)$
# * inner function derivative wrt. b: -1
#
#
# * chain rule:  $2*(y^j - wx^j - b) * (-1)$
#
#
# $2(y_i - mx_i -b)(-1)=0$ iff $(y_i - mx_i -b)=0$
#
# $$ \frac{\delta J(w,b)}{\delta b}= 0 ~~iff \sum_{i=1}^n[y_i - wx_i -b] = 0 $$
# * addition and substraction are assoziative: e.g. (4-1)+(5-2) = (4+5) + (-1-2) = 9 - 3 = 6
#
# $$[\sum_{i=1}^n y_i] - [w \sum_{i=1}^n x_i] - [nb] = 0$$
#
# we divide by $n$ and resolve for b and get: $\bar{y} = \frac{\sum_{i=1}^n y_i}{n}$ and $\bar{x} =  \frac{\sum_{i=1}^n x_i}{n}$
#
# it follows: $$ b = \bar{y}-w\bar{x}$$
#
# in the original formula, we replace $b$ by $b = \bar{y}-w\bar{x}$
#
# $$J(w,b)= \sum_{i=1}^n (y_i - f(x_i))^2 = \sum_{i=1}^n (y_i - wx_i -  \bar{y}+w\bar{x})^2$$
#
# again we use the chain rule to partially derive wrt. $w$
#
# $$\frac{\delta J(w,b)}{\delta w}= \sum_{i=1}^n2(y_i - wx_i - \bar{y} + w\bar{x})(-x_i + \bar{x})=0$$
#
# which gives (without 2, permuted):
#
# $$\frac{\delta J(w,b)}{\delta w}= \sum_{i=1}^n(-1 (\bar{y} - y_i ) +  (w\bar{x}- wx_i))( \bar{x} - x_i )=0$$
#
# which gives:
#
# $$\frac{\delta J(w,b)}{\delta w}= - \sum_{i=1}^n (\bar{y}-y_i  )( \bar{x} - x_i ) +  w \sum_{i=1}^n(\bar{x}- x_i)^2=0$$
#
# resolved wrt. $w$:
# $$w = \frac{\sum_{i=1}^n(\bar{y}-y_i)(\bar{x}-x_i)}{\sum_{i=1}^n(\bar{x}-x_i)^2}$$
#
# $i$ here is the example index
#
# ## Finding the hyperplane for our examples
#
# * $x^1 = (2,4)$
# * $x^2 = (2,2)$
#
#
# * $\bar{x}=2$
# * $\bar{y}=3$
#
# $w = 0$ since $(\bar{x}-x_i) = 0$ (for each $x_i$) in  $$\frac{\sum_{i=1}^n(\bar{y}-y_i)(\bar{x}-x_i)}{\sum_{i=1}^n(\bar{x}-x_i)^2}$$
#
# $b= \bar{y}-w\bar{x}=3 - 0 = 3$

# %%
plt.plot([0,2,4],[3,3,3])
plt.plot([2],[2],'bo')
plt.plot([2],[4],'go')
plt.plot([0],[0])

plt.show()

# %% [markdown]
# This was a closed form solution (we actually determined it by solving the equation)
#
#
# We could rather use a iterative approach called gradient descend

# %% [markdown]
# ## Absorb the bias term $b$
#
# We have two weights. In order to simplify notation but otherwise do exactely the same as before, we absorb $b$ into $w$ (weight vector) and $x$ (feature vector).
#
# That is $b$ can be learned as well, and (then) it is always active.
#
# * $w=(b,w_1,w_2,\ldots)$
#
#
# * $x=(1,x_1,x_2,\ldots)$  the first entry is a dummy feature that guarantees that $b$ is active
#
#
# then we no longer refer to $b$ in our derivations

# %% [markdown]
# # Gradient Descend
#
# The derivation of our error function $J$ (now the general form, not just with the two parameter $w$ and $b$). We use the chain rule.
#
# ![deriv.png](attachment:deriv.png)
#
# the last line gives as the slope of the convex cost function at each point
#
# procedure: we initialize $w$ randomly, we apply $J$ and get a value which is just a  particular point on the curve:
#
# ![rasch_grad.png](attachment:rasch_grad.png)
#
# * our point has a its sign either plus or minus
#
#
# * if it is plus something, then we have to lower the weight (we are to the right of the minimum)
# * if it is minus something, we have to increase the weigth (we are to the left of the minimum)
#
# * to what extend should decrease or increase?
# * in order to avoid missing the minimum, we should do it slowly
#
# * we define a learning rate $\eta$
#
#
#   $$\Delta(w_j)=-\eta \frac{\partial  J}{\partial w_j}$$
#
# i.e. for each weight $w_j$ we deterine a delta, some correction of the weight, scaled by $\eta$
#
# * if the slope is negative, we get a plus (minus + minus = plus). The adapted weight is then: $w_j=w_j+\Delta w_j$
# * if the slope is positive, we get a minus (minus + plus = minus). The adapted weight is then: $w_j=w_j-\Delta w_j$

# %%
X1=[2]   # vector 1
X2=[2]   # vector 2 

Y1=4       # y of vector 1 observed
Y2=2       # y of vector 2 observed

w1=0.5     # arbitrary weight

eta=0.1    # learning rate

# %% [markdown]
# the initial hyperplane is: $y=0.5*x1

# %%
# prediction with dot product

import numpy as np

np.dot([w1],X1)
# Out:
# 1.0

# %% [markdown]
# $y$ prediction is 1 for both instances $x^1, x^2$ with 4, 2 as $y_{obs}$
#
# eq 1 (slope): $-\sum_{i=1}^{n=2}(y^{(i)}-w^Tx^{(i)})x_j^{(i)}$ (first (partial) derivative of $J$ wrt. to $w_j$)
#
# $x^{(i)}$: $i$ is the index of example
#
# $w^Tx^{(i)}~~~~$ in Python: $~~~~$np.dot([w1],X1)

# %%
# X1=[2], X2=[2], w1=[0.5], Y1=4, Y2=2

def deriv(j):  # weight j (we have only one)
    """ the (slope of) error is the sum of the individual errors (slopes), i.e. with respect to all examples 
        (here only X1, X2)
        j is the index of the weight we adjust (j is set by the function call)
    """
    return -((Y1-np.dot([w1],X1))*X1[j]+    # j=0, X1[j]=2
             (Y2-np.dot([w1],X2))*X2[j])

# %% [markdown]
# The error function $err$ is defined as the 1. derivative of $J$. In the definition above, we replace the sum by a simple addition (we only have 2 term to sum.
#
# $X1$ is the x value of the weight under consideration (given some example)
#
# Here is the so-called Delta rule (we increment/decrement the weight)

# %%
w1= w1 +  (-eta *  deriv(0))   
w1
# Out:
# 1.3

# %%
# prediction of y with the adapted weight

np.dot([w1],X1),np.dot([w1],X2)

# %%
# new adaption

w1= w1 +  (-eta *  deriv(0))   
w1
# Out:
# 1.46

# %%
np.dot([w1],X1),np.dot([w1],X2)
# Out:
# (2.92, 2.92)

# %% [markdown]
# we do it in a loop n times (called epochs)

# %%
# it converges at 3 for y, the weight converges at 1.5

epochs=200

i=0
while i < epochs:
    w1= w1 + (-eta * deriv(0))  # Adaption von Gewicht w1
    i+=1
    

print("predictions:",np.dot([w1],X1),np.dot([w1],X2),"    final weight:",w1)
# Out:
# predictions: 3.0 3.0     final weight: 1.5

# %% [markdown]
# ## regression versus (binary) classification
#
# Taken as regression: we would predict 3 for both instances (determine y given x): lowest error possible
#
# Regarded as a classification task (we assume now $x^1$ and $x^2$ to belong to distinct classes), we determine the value of the decision boundary and take the sign of it.
#
# ### decision boundary
#
# our new formula is (remember, we started with f(x)=0.5x):
#
# $f(x)=w * x$ where w = 1.5 (the learning result, the hyperplane)
#
# This is our decision boundary (and thus our classifier):
#
# * $x_2 - 1.5 * x_1 = 0~~~~$ or $~~~~-1.5x_1 + x_2 = 0~~~~$ (we use the last ordering)
#
#
# * $w = [-1.5,1]$
# * $x = [x_1,x_2]$
#
# We apply it to (i.e. classify) our examples:
#
# * $-1.5 * 2 + 4 = 1$  (vector 1: above the line)
#
# * $-1.5 * 2 + 2= -1$ (vector 2 below the line)
#
# i.e the examples of the different classes are perfectly separated/approximated by our line; we could not do any better (only at higher costs)

# %%
# first arg: x values, sec. arg: y values
plt.plot([0,1,2,2.5],[0,1.5,3,3.75])
plt.plot([2],[2],'bo')
plt.plot([2],[4],'go')

plt.show()

# %%
w = [-1.5,1]

# ordering is [y,x]
x1=[2,4]

x2=[2,2]

np.dot(w,x1),np.dot(w,x2)  # we don't need the sign function here, but in general we do
# Out:
# (1.0, -1.0)

# %% [markdown]
# ### All in all

# %%
# Gradient Descend for hyperlane learning (minimizing the error)
import numpy as np

X1=[2]
X2=[2]

Y1=4
Y2=2

w1=0.5

eta=0.01    # the learning rate

def deriv(j): # the value of the first derivative
    
    return -((Y1-np.dot([w1],X1))*X1[j]+    
             (Y2-np.dot([w1],X2))*X2[j])    

def error():  # squared error
    
    return  ((Y1-np.dot([w1],X1))**2+    
             (Y2-np.dot([w1],X2))**2)    


epochs=100
i=0
w,e=[],[]
while i < epochs:
    w.append(w1)
    e.append(error())
    w1= w1 + (-eta * deriv(0))
    i+=1
    

np.dot([w1],X1),np.dot([w1],X2)
# Out:
# (2.999521576250686, 2.999521576250686)

# %% [markdown]
# Note: the error is minimized because the hyperplane is exactly inbetween the two point. If we move it towards on of the point the error $J$ increases (because of the square)

# %%
# the progression of the weight and the error

w,e

# %%
plt.plot(w,e)

plt.show()

# %%
# if we start with a higher weight: 10 instead of 0.5
# we get the righthand side of the parabel

w1=10

eta=0.01

epochs=100
i=0
w,e=[],[]
while i < epochs:
    w.append(w1)
    e.append(error())
    w1= w1 + (-eta * deriv(0))
    i+=1
    
np.dot([w1],X1),np.dot([w1],X2)
# Out:
# (3.004066601869169, 3.004066601869169)

# %%
plt.plot(w,e)

plt.show()

# %% [markdown]
# ## Heaviside step function
#
# The distance of point to the hyperplane normally is different from 1. We thus map it with e.g. the *Heaviside  step function (unit_step)* e.g. $\theta=0$) to its (algebraic) sign (above we used np.sign, but we cannot set a threshold, which we somestimes would like to do):
#
#
#
#
# $$\hat{y} = \phi({x})= \left \{ \begin{array}{ll}
# 1 &if~ x \geq \theta\\
# -1 &if~ x < \theta\\
#  \end{array}
# \right .$$
#
# we use $\phi$ (phi) to denote the function and $\theta$ (theta) to denote the threshold

# %%
theta=0
unit_step = lambda x: -1 if x < theta else 1

unit_step(-4),unit_step(2)
# Out:
# (-1, 1)

# %%
# classifying a new point (the red plus)

plt.plot([0,1,2,2.5],[0,1.5,3,3.75])
plt.plot([2],[2],'bo')
plt.plot([2],[4],'go')
plt.plot([1],[3],'r+')


plt.show()

# %%
w=[-1.5,1]
X3=[1,3]                                # prediction of the position of a new instance
np.dot(w,X3),unit_step(np.dot(w,X3))    # first the distance to the hyperplane, then the side (which is 1)
# Out:
# (1.5, 1)

# %% [markdown]
# # Wrap up (so far)
#
# Given linear separability, then we can find a separating/approximating line between objects that can be used for regression or as a classifier. The cost function is fundamental, e.g. least squared distance. This allows both regression and classification to be realized. An important technique is the gradient descent method, the gradient is given by the derivative of the error function, its sign determines the direction of the weight adaptation. Learning is therefore the optimization of a weight vector.
#
# Conceptually, the idea behind the gradient method is extremely simple:
#
# * $y = unit\_step(w_0*x_0 + w_1*x_1, .., w_n*x_n$), with $\theta$ as an arbitrary threshold (e.g. 0)
#
#
# * note: a threshold other than zero might have influence on eta and the number of epochs
#
#
# * if $y$ is smaller than $\theta$, we have to increase the weights (slightly)
#
#
# * otherwise we have to decrease
#
# Again for clarification: the principle is maximally simple - if the function to be learned returns a value that is erroneously above the threshold value, the weights must be reduced (by a small amount), otherwise they are incremented.
#
# We have answered the question how to do this inrementation or decrementation in a systemic way.
#
# This very basic approach dates back to the work of Frank Rosenblatt in 1958 (see below): the perceptron algorithm

# %% [markdown]
# ## sklearn (scikit-learn)
#
# sklearn is a machine learning library for the Python for classification, regression and clustering, e.g. support vector machines, random forests and knn.
#
# * uniform interface to learning algorithm
# * object-oriented
#
# * use an array $X$ of array to represent data
# * use an array of labels $y$ to represent classes
# * draw an instance of the learning approach (class)
# * "fit(X,y)" means "learn"
# * use "predict" to classify new examples

# %% [markdown]
# ## Perceptron (Frank Rosenblatt 1958)
#
# * meant as a simplified model of human brain: neurons and synapses
# * we have an activation and a threshold
# * if the activation $a$ is higher than the threshold $\theta$: neuron fires
# * step function models firing of neurons
# * heaviside(x) = y = $\left \{ \begin{array}{ll}
# 1 &if~ a > \theta\\
# 0 &if~ a < \theta\\
#  \end{array}
# \right .$
#
# ![perceptron.png](attachment:perceptron.png)
#
# * it's just a linear function: $x_1*w_1+\ldots+x_i*w_i+\ldots+x_n*w_n = \Sigma$
#
#
# * if $\Sigma>\theta$ then $y=1$ otherwise $y=0$
#
#
# * Note: we are free to specify the output of step function, we could as well have used -1 (as we did so far)

# %%
from sklearn.linear_model import Perceptron

clf = Perceptron(max_iter=600)

X=[[2,4],[2,2]]
y=[1,0]

clf.fit(X, y)

clf.predict([[1,3]])
# Out:
# array([1])

# %%
# inspect the model: intercept = y offset (we called it "b"), coef = the weights

clf.intercept_,clf.coef_
# Out:
# (array([-1.]), array([[-2.,  2.]]))

# %% [markdown]
# ## Probability of class membership
#
# * So far: a binary decision of class membership
# * the perceptron does not give us a probability, just a class
# * how to get the probability of class membership
#
#
# * derivation of the sigmoid formula(s): see script derivation.pdf
# * idea: map values of the classifier to intervall [0..1] - with a corresponding function, e.g. sigmoid
#
# Note: The following is just in order to illustrate the very idea. In order to incoporate simoid properly in the learning process, we have to integrate it into the derivation of $J$.
#
# Redefinition (broadly): the error $J$ is now dependent of the 1st derivative of the sigmoid function as well

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
    
def sigmoid_plot(x):   # only for ploting
    a = []
    for item in x:
        a.append(1/(1+math.exp(-item)))
    return a

x = np.arange(-10., 10., 0.2)
sig = sigmoid_plot(x)

plt.plot(x,sig)
plt.show()

# %% [markdown]
# $$ sigmoid(x=1)= \frac{1}{(1+e^{-x})}$$
#
# $$ sigmoid(x=0)= \frac{1}{(1+e^{x})}$$

# %%
def pos(x):   # sigmoid function: probability of class 1
    return 1/(1+math.exp(-x))

def neg(x):  # sigmoid function: probability of class 0
    return 1/(1+math.exp(x))

w=[-1.5,1]
X3=[1,3]                                # prediction of the class of a new instance

np.dot(w,X3),pos(np.dot(w,X3))

# pos(-6),neg(-6),pos(6),neg(6)
# Out:
# (1.5, 0.8175744761936437)

# %% [markdown]
# ## Supervised Setting
#
# So far, we treated learning as a regression task: find the hyperplane best approximating a couple of points. We actually predicted values (well $y$) and claimed that we could map such predictions to positions (above, below). If we are interested in regression, we would stick with the predicted values (with $y$). If we have classes in mind, we map values to class indicators.

# %%
plt.plot([0,1,2,2.5],[0,1.5,3,3.75])
plt.plot([2],[2],'bo')
plt.plot([2],[4],'go')

plt.show()

# %% [markdown]
# ## Representing the class
#
# We add a final (in our case third) dimension that represents the class: 1 or -1 (sometimes 0 is used)
#
# * (2,2) becomes (2,2,-1)
# * (2,4) becomes (2,4,1)
# * the new point (2,3) becomes (2,3,1) (for example)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')

ax.scatter(2,4,1,c='b',marker='o')
ax.scatter(2,2,-1,c='r',marker='^')
ax.scatter(2,3,1,c='b',marker='o')
ax.scatter(1,2,-1,c='r',marker='^')  # some additional point 

plt.show()

# %%
import numpy as np

X1=[2,4]
X2=[2,2]

Y1=1    # supervised setting: class of X1 is 1
Y2=-1

w=[1,1] # arbitrary set weight vector

eta=0.01    # the learning rate

def deriv(j): # the value of the first derivative
    
    return -((Y1-np.dot(w,X1))*X1[j]+(Y2-np.dot(w,X2))*X2[j])    

epochs=1000
i=0
while i < epochs:
    w[0]= w[0] + (-eta * deriv(0))
    w[1]= w[1] + (-eta * deriv(1))
    i+=1
    
np.dot(w,X1),np.dot(w,X2),pos(np.dot(w,X2)),neg(np.dot(w,X2))
# Out:
# (0.9983199108192884,
#  -0.9971963101331689,
#  0.2694930172265459,
#  0.730506982773454)

# %% [markdown]
# ## (Derivation of the)  Cost function with sigmoid
#
# The cost function for the dot product scenario (b absorbed):
#
# $$J(w_j) = \sum_{i=0}^M(y^i - w_jx^i)^2$$
#
# The cost function for the sigmoid scenario:
#
# $$J(w) = \sum_{j=0}^M(y^j - \sigma(wx^j))^2$$
#
#
# $\sigma(x) = \frac{1}{1+e^{-x}}~~~$ with the first derivative: $~~~\sigma(x)' = \sigma(x)(1-\sigma(x))$
#
# * partial derivative:
#
# $$\frac{\delta J(w)}{\delta w^j}$$
#
# * chain rule in Leibnitz notation:
#
# $$\frac{\delta J(w)}{\delta w^j}= \frac{\delta J}{\delta z} * \frac{\delta z}{\delta \sigma} * \frac{\delta \sigma}{\delta w^j}$$
# where $z = y_i - g(w^jx_i)^2$

# %% [markdown]
# # Wrap up
#
# * the perceptron only gives class predictions
# * logistic regression gives probabilities
